# %% [markdown]
# <a href="https://www.kaggle.com/code/laxurie/mouis-part-3?scriptVersionId=315724251" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## Part 3: Sales Forecasting Pipeline
#
# This notebook runs the full reproducible forecasting pipeline for Datathon 2026 Round 1.
#
# Main steps:
# 1. Load official competition data only.
# 2. Generate calendar, event, lag, rolling, promotion and operational features.
# 3. Train baseline and ensemble models using time-series cross-validation.
# 4. Validate using MAE, RMSE and R².
# 5. Generate final submission with Date, Revenue, COGS.

# %%
print("Current working directory:", os.getcwd())
print("Files in MODEL_Final:")
for root, dirs, files in os.walk("."):
    level = root.replace(".", "").count(os.sep)
    indent = "  " * level
    print(f"{indent}{os.path.basename(root)}/")
    for f in files[:10]:
        print(f"{indent}  {f}")

# %%
import os

path = '/kaggle/input/competitions/datathon-2026-round-1'

for dirname, _, filenames in os.walk(path):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import os
import shutil

def setup_and_run_pipeline():
    # Cập nhật đường dẫn mới theo dataset bạn vừa up
    input_dir = '/kaggle/input/datasets/laxurie/mouis-final/MODEL_Final'
    working_dir = '/kaggle/working/MODEL_Final'

    # 1. Copy dataset to writable working directory
    if not os.path.exists(working_dir):
        shutil.copytree(input_dir, working_dir)

    # 2. Set working directory
    os.chdir(working_dir)

    # 3. Install required dependencies
    os.system('pip install -q catboost lightgbm xgboost')

    # 4. Execute the modeling pipeline
    print("Executing modeling pipeline...")
    os.system('python pipeline.py')

    # 5. Export final submission file
    # Đã cập nhật tên file theo bản clean mới nhất
    champion_file = "final_submission.csv"
    submission_path = "/kaggle/working/submission.csv"
    
    if os.path.exists(champion_file):
        shutil.copy(champion_file, submission_path)
        print(f"Success: Submission file saved to {submission_path}")
    else:
        print("Error: Pipeline failed to generate the champion submission file.")

if __name__ == "__main__":
    setup_and_run_pipeline()
