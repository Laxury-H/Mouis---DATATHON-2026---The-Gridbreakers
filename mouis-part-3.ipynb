# %% [markdown]
# <a href="https://www.kaggle.com/code/laxurie/mouis-part-3?scriptVersionId=315650090" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import os
import shutil

def setup_and_run_pipeline():
    # Define source and destination directories
    input_dir = '/kaggle/input/datasets/laxurie/mouis-v33/MODEL_Final'
    working_dir = '/kaggle/working/MODEL_Final'

    # 1. Copy dataset to writable working directory
    if not os.path.exists(working_dir):
        shutil.copytree(input_dir, working_dir)

    # 2. Set working directory
    os.chdir(working_dir)

    # 3. Install required dependencies
    os.system('pip install -q catboost lightgbm xgboost')

    # 4. Execute the modeling pipeline
    print("Executing V33 modeling pipeline...")
    os.system('python pipeline.py')

    # 5. Export final submission file
    champion_file = "LaHuy_Submission_V33_Champion.csv"
    submission_path = "/kaggle/working/submission.csv"
    
    if os.path.exists(champion_file):
        shutil.copy(champion_file, submission_path)
        print(f"Success: Submission file saved to {submission_path}")
    else:
        print("Error: Pipeline failed to generate the champion submission file.")

if __name__ == "__main__":
    setup_and_run_pipeline()
# Out:
# Executing V33 modeling pipeline...
# holdout_revenue_mae 712694.0899012741
# holdout_cogs_mae 581792.0078515062
# oof_revenue_mae 1304355.3654693956
# best_beta_diff_blend 0.35000000000000003
# dynamic_multiplier_gamma 0.7000000000000001
#
# 🏆 Đã tạo siêu phẩm Post-processing: submission_v18_scaled_mean_445.csv
# Mean Revenue mục tiêu: 4450000.0 | Scaling factor: 0.8974
#
# created submission_v18_dl_stack_raw.csv
# sha256 6610d1e201b1d148ef59bf5bc3e366d38ec219e963bedfd510ca7c27ad1b77bb
# mean_revenue 4450000.0 mean_cogs 3947856.7975231973 mean_ratio 0.8866176142478572
# mae_vs_g26_revenue 592055.9900696566 mae_vs_g26_cogs 537248.0100862922 mae_vs_g26_ratio 0.031827040649728085
#
# created submission_v18_dl_stack_anchor_a22.csv
# sha256 4a76f0c0f8a353fb3e784f7ac7a2a589c698dbcc8792aec677d2e76c23e47fb5
# mean_revenue 4284068.814722336 mean_cogs 3763871.494636575 mean_ratio 0.8789530146420209
# mae_vs_g26_revenue 130252.31781532441 mae_vs_g26_cogs 116897.177635974 mae_vs_g26_ratio 0.00700194894294019
# 🚀 [V25 COMPONENT STACK] Bóc tách Orders và AOV...
# \n🎯 Đang xử lý: total_orders
#   ✅ Seed 1 done
#   ✅ Seed 2 done
#   ✅ Seed 3 done
#   ✅ Seed 4 done
#   ✅ Seed 5 done
#   ✅ Seed 6 done
#   ✅ Seed 7 done
#   ✅ Seed 8 done
#   ✅ Seed 9 done
#   ✅ Seed 10 done
#   🔮 Dự báo đệ quy cho total_orders...
#   👉 total_orders Mean Forecast: 122.06
# \n🎯 Đang xử lý: AOV
#   ✅ Seed 1 done
#   ✅ Seed 2 done
#   ✅ Seed 3 done
#   ✅ Seed 4 done
#   ✅ Seed 5 done
#   ✅ Seed 6 done
#   ✅ Seed 7 done
#   ✅ Seed 8 done
#   ✅ Seed 9 done
#   ✅ Seed 10 done
#   🔮 Dự báo đệ quy cho AOV...
#   👉 AOV Mean Forecast: 26,650.31
# \n📊 Kết hợp Revenue = Orders * AOV...
# Raw Revenue Mean = 3,218,679
# ⚖️ Scale factor: 1.3826
# ✅ Đã lưu Raw: submission_v25_comp_stack_raw.csv
# ✅ Đã lưu Anchor 50%: submission_v25_comp_stack_anchor_50.csv
# 🚀 [V25 SWEEP] Tạo bản mix V18 và V25 (Alpha=0.3)...
# ✅ Đã tạo: submission_v25_blend_v18_a30.csv
# \n📁 Tất cả file đã lưu tại: /kaggle/working/MODEL_Final/results/submissions/v25_sweeps
# 🚀 [V28 ONE-SHOT COMPONENTS] Khởi động: Bóc tách Orders x AOV + Phi Đệ Quy...
# \n🎯 Đang xử lý Component: total_orders
#   ✅ Seed 1 done
#   ✅ Seed 2 done
#   ✅ Seed 3 done
#   ✅ Seed 4 done
#   ✅ Seed 5 done
#   ✅ Seed 6 done
#   ✅ Seed 7 done
#   ✅ Seed 8 done
#   ✅ Seed 9 done
#   ✅ Seed 10 done
#   👉 total_orders Forecast Mean: 187.00
# \n🎯 Đang xử lý Component: AOV
#   ✅ Seed 1 done
#   ✅ Seed 2 done
#   ✅ Seed 3 done
#   ✅ Seed 4 done
#   ✅ Seed 5 done
#   ✅ Seed 6 done
#   ✅ Seed 7 done
#   ✅ Seed 8 done
#   ✅ Seed 9 done
#   ✅ Seed 10 done
#   👉 AOV Forecast Mean: 26,707.38
# \n📊 Kết hợp Revenue = Orders * AOV...
# Raw Revenue Mean = 4,941,428
# ⚖️ Scale factor: 0.9005
# ✅ Đã lưu Raw: submission_v28_oneshot_comp_raw.csv
# ✅ Đã lưu Anchor 30%: submission_v28_oneshot_comp_anchor_30.csv
# 🚀 TIME-DECAY BLENDING + SYNC COGS: Fading out Recursive, Fading in One-Shot...
#
# 🏆 SIÊU PHẨM ĐÃ HOÀN THÀNH: /kaggle/working/MODEL_Final/LaHuy_Submission_V33_Champion.csv
# 📊 Mean Revenue: 4,376,804
# =====================================================
# 🏆 REPRODUCING V33 TIME-DECAY BLEND (664k MAE) 🏆
#    FOLDER: LaHuy
# =====================================================
#
# 🚀 Running src/model_v18_dl_stack.py...
# ✅ Finished src/model_v18_dl_stack.py
#
# 🚀 Running src/model_v25_components.py...
# ✅ Finished src/model_v25_components.py
#
# 🚀 Running src/blend_v25_sweep.py...
# ✅ Finished src/blend_v25_sweep.py
#
# 🚀 Running src/model_v28_oneshot_components.py...
# ✅ Finished src/model_v28_oneshot_components.py
#
# 🚀 Running src/blend_time_decay.py...
# ✅ Finished src/blend_time_decay.py
#
# 🧹 Cleaning up intermediate files...
#
# 🎉 All models executed successfully!
# =====================================================
# 🏆 FINAL CHAMPION SUBMISSION: /kaggle/working/MODEL_Final/LaHuy_Submission_V33_Champion.csv
# =====================================================
# Success: Submission file saved to /kaggle/working/submission.csv
